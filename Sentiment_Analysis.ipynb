# %% [markdown]
# <a href="https://colab.research.google.com/github/ithadisushmitha/Sentiment-Analysis/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import snscrape.modules.twitter as sntwitter

# %%
k='(#covid-19 OR #booster OR #dose) min_retweets:5000 lang:en until:2022-11-30 since:2020-03-20'
l=[]
for tweet in sntwitter.TwitterSearchScraper(k).get_items():
  if len(l)==100:
    break
  else:
    l.append(tweet.renderedContent)

# %%
print(l)
# Out:
# ['George Soros: “Covid-19 also helped legitimize instruments of control”…  \n\nThey are saying the quiet part out loud.\n\n🔊sound ...🧐😰 https://t.co/Qo1UN0f1C9', 'This winter flu that’s going around is Covid-19’s cousin for sure.', 'BREAKING: A peer-reviewed study shows a 42% false positive rate for COVID-19 from the nonQ-RT-PCR Test. \n\nAll COVID-19 jab studies used nonQ-RT-PCR to determine case status, which means COVID-19 jab outbreak data is unreliable and flawed.\n\nThis is shocking.', 'Matt Hancock isn’t a ‘celebrity’, he’s the former health secretary who oversaw the UK having one of the highest death tolls in the world from Covid-19 whilst breaking his own lockdown rules.\n\n1/5', '🚨🚨🚨🚨🚨\nNY State Supreme Court reinstates all fired unvaccinated employees, orders backpay, says the state violated rights, acted arbitrary &amp; capricious, notes:“Being vaccinated does not prevent an individual from contracting or transmitting Covid-19.”\niapps.courts.state.ny.us/fbem/DocumentD… h
# ...

# %% [markdown]
# ## **Data** **Preprocessing**

# %% [markdown]
# 1 Cleaning(Removing symbols and punctuations)

# %% [markdown]
# [ #Character block start.
# ^ #not these characters(letters, numbers).
# \w #word characters.
# \s #space characters.
# ] #character block end.

# %%
punctuations = '''!()-{}[];:'"\,<>./?@#$%^&*_~'''
no_punct=""
for char in l:
  if(char not in punctuations):
    no_punct = no_punct+char
no_punct
# Out:
# 'George Soros: “Covid-19 also helped legitimize instruments of control”…  \n\nThey are saying the quiet part out loud.\n\n🔊sound ...🧐😰 https://t.co/Qo1UN0f1C9This winter flu that’s going around is Covid-19’s cousin for sure.BREAKING: A peer-reviewed study shows a 42% false positive rate for COVID-19 from the nonQ-RT-PCR Test. \n\nAll COVID-19 jab studies used nonQ-RT-PCR to determine case status, which means COVID-19 jab outbreak data is unreliable and flawed.\n\nThis is shocking.Matt Hancock isn’t a ‘celebrity’, he’s the former health secretary who oversaw the UK having one of the highest death tolls in the world from Covid-19 whilst breaking his own lockdown rules.\n\n1/5🚨🚨🚨🚨🚨\nNY State Supreme Court reinstates all fired unvaccinated employees, orders backpay, says the state violated rights, acted arbitrary &amp; capricious, notes:“Being vaccinated does not prevent an individual from contracting or transmitting Covid-19.”\niapps.courts.state.ny.us/fbem/DocumentD… https://t.co/WhH4w
# ...

# %%
str1 = no_punct

# %% [markdown]
# # **Tokenization**

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.word_tokenize(str1)
# Out:
# ['George',
#  'Soros',
#  ':',
#  '“',
#  'Covid-19',
#  'also',
#  'helped',
#  'legitimize',
#  'instruments',
#  'of',
#  'control',
#  '”',
#  '…',
#  'They',
#  'are',
#  'saying',
#  'the',
#  'quiet',
#  'part',
#  'out',
#  'loud',
#  '.',
#  '🔊sound',
#  '...',
#  '🧐😰',
#  'https',
#  ':',
#  '//t.co/Qo1UN0f1C9This',
#  'winter',
#  'flu',
#  'that',
#  '’',
#  's',
#  'going',
#  'around',
#  'is',
#  'Covid-19',
#  '’',
#  's',
#  'cousin',
#  'for',
#  'sure.BREAKING',
#  ':',
#  'A',
#  'peer-reviewed',
#  'study',
#  'shows',
#  'a',
#  '42',
#  '%',
#  'false',
#  'positive',
#  'rate',
#  'for',
#  'COVID-19',
#  'from',
#  'the',
#  'nonQ-RT-PCR',
#  'Test',
#  '.',
#  'All',
#  'COVID-19',
#  'jab',
#  'studies',
#  'used',
#  'nonQ-RT-PCR',
#  'to',
#  'determine',
#  'case',
#  'status',
#  ',',
#  'which',
#  'means',
#  'COVID-19',
#  'jab',
#  'outbreak',
#  'data',
#  'is',
#  'unreliable',
#  'and',
#  'flawed',
#  '.',
#  'This',
#  'is',
# ...

# %%
str1.split(' ')
# Out:
# ['George',
#  'Soros:',
#  '“Covid-19',
#  'also',
#  'helped',
#  'legitimize',
#  'instruments',
#  'of',
#  'control”…',
#  '',
#  '\n\nThey',
#  'are',
#  'saying',
#  'the',
#  'quiet',
#  'part',
#  'out',
#  'loud.\n\n🔊sound',
#  '...🧐😰',
#  'https://t.co/Qo1UN0f1C9This',
#  'winter',
#  'flu',
#  'that’s',
#  'going',
#  'around',
#  'is',
#  'Covid-19’s',
#  'cousin',
#  'for',
#  'sure.BREAKING:',
#  'A',
#  'peer-reviewed',
#  'study',
#  'shows',
#  'a',
#  '42%',
#  'false',
#  'positive',
#  'rate',
#  'for',
#  'COVID-19',
#  'from',
#  'the',
#  'nonQ-RT-PCR',
#  'Test.',
#  '\n\nAll',
#  'COVID-19',
#  'jab',
#  'studies',
#  'used',
#  'nonQ-RT-PCR',
#  'to',
#  'determine',
#  'case',
#  'status,',
#  'which',
#  'means',
#  'COVID-19',
#  'jab',
#  'outbreak',
#  'data',
#  'is',
#  'unreliable',
#  'and',
#  'flawed.\n\nThis',
#  'is',
#  'shocking.Matt',
#  'Hancock',
#  'isn’t',
#  'a',
#  '‘celebrity’,',
#  'he’s',
#  'the',
#  'former',
#  'health',
# ...

# %% [markdown]
# # **Removing** **stopwords**

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(STOPWORDS)
# Out:
# {'i', 'whom', 'has', 'very', 'because', 'will', 'over', 'couldn', 'these', 'its', "that'll", 'our', 'be', 'been', 'or', 'once', "mustn't", 'up', 's', 'here', 'yourself', 'not', 'y', 'those', 'after', 'with', 'for', 'from', 've', 'did', 'same', 'few', 'their', 'his', "isn't", "mightn't", 'hadn', 'does', 'isn', 'to', 'm', 'being', 'we', 'me', 'hasn', 'aren', 'herself', 'hers', "wasn't", 'a', 'before', 'by', 'have', 'under', 'off', "don't", 'shouldn', 'who', 'doesn', 'o', "you've", 'is', "shouldn't", 'in', 'above', "needn't", 'during', 'more', 'll', 'this', 'wouldn', 'all', 'don', 'only', 'just', 'himself', "didn't", 'where', "couldn't", 'haven', 'an', 'itself', 'myself', 'down', 'then', 'now', 'ours', 'so', 'should', 'each', 'some', "wouldn't", 'again', 'won', 'yourselves', 'which', 'having', 'mustn', 'into', 'needn', 'the', 'most', "haven't", "it's", 'ourselves', 'doing', 'out', 'ain', 'of', 'but', "she's", 'themselves', 'had', "hadn't", 'they', 'any', 'd', 'what', 'shan', 'yours', 'w
# ...

# %%
m=""
for i in str1:
  if(i not in STOPWORDS):
    m = m+i
m
# Out:
# 'Gerge Sr: “Cv-19 l helpe legze nruen f cnrl”…  \n\nThe re ng he que pr u lu.\n\n🔊un ...🧐😰 hp://.c/Q1UN0f1C9Th wner flu h’ gng run  Cv-19’ cun fr ure.BREAKING: A peer-revewe u hw  42% fle pve re fr COVID-19 fr he nnQ-RT-PCR Te. \n\nAll COVID-19 jb ue ue nnQ-RT-PCR  eerne ce u, whch en COVID-19 jb ubrek   unrelble n flwe.\n\nTh  hckng.M Hncck n’  ‘celebr’, he’ he frer helh ecrer wh verw he UK hvng ne f he hghe eh ll n he wrl fr Cv-19 whl brekng h wn lckwn rule.\n\n1/5🚨🚨🚨🚨🚨\nNY Se Supree Cur rene ll fre unvccne eplee, rer bckp,  he e vle rgh, ce rbrr &p; cprcu, ne:“Beng vccne e n preven n nvul fr cnrcng r rnng Cv-19.”\npp.cur.e.n.u/fbe/DcuenD… hp://.c/WhH4wje2bQA lng  I  Gvernr, n Flr here wll n be  COVID-19 vccne ne fr chlren n ur chl. hp://.c/DXAj3c4OThe echn f SARS2? Enhell ge. In pln Englh? Cv-19 fuck up he lnng f ur bl veel. All 60,000 le f . Bl veel lck nerve. Yu feel OK   e ur rere. Den\' en \' "l." I en he enhelu n\' nnerve.The purche f 4.5 blln e f he cv-19 vccne fr 450 lln EU
# ...

# %%
str2=m

# %% [markdown]
# ## **Removing** **Emojis**

# %%
pip install clean-text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import clean function
from cleantext import clean

#provide string with emojis
text = str2

#print text after removing the emojis from it
print(clean(text, no_emoji=True))
# Out:
# gerge sr: "cv-19 l helpe legze nruen f cnrl"
# the re ng he que pr u lu.
# un ... hp://.c/q1un0f1c9th wner flu h' gng run cv-19' cun fr ure.breaking: a peer-revewe u hw 42% fle pve re fr covid-19 fr he nnq-rt-pcr te.
# all covid-19 jb ue ue nnq-rt-pcr eerne ce u, whch en covid-19 jb ubrek unrelble n flwe.
# th hckng.m hncck n' 'celebr', he' he frer helh ecrer wh verw he uk hvng ne f he hghe eh ll n he wrl fr cv-19 whl brekng h wn lckwn rule.
# 1/5
# ny se supree cur rene ll fre unvccne eplee, rer bckp, he e vle rgh, ce rbrr &p; cprcu, ne:"beng vccne e n preven n nvul fr cnrcng r rnng cv-19."
# ...

# %% [markdown]
# ## **Lemmatization**

# %%
text = str2

# %%
import nltk
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

sentence = text
sentence_words = nltk.word_tokenize(sentence)

# %%
import nltk
nltk.download('omw-1.4')
for word in sentence_words:
  print(wordnet_lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Gerge
# Sr
# :
# “
# Cv-19
# l
# helpe
# legze
# nruen
# f
# cnrl
# ”
# …
# The
# re
# ng
# he
# que
# pr
# u
# lu
# .
# 🔊un
# ...
# 🧐😰
# hp
# :
# //.c/Q1UN0f1C9Th
# wner
# flu
# h
# ’
# gng
# run
# Cv-19
# ’
# cun
# fr
# ure.BREAKING
# :
# A
# peer-revewe
# u
# hw
# 42
# %
# fle
# pve
# re
# fr
# COVID-19
# fr
# he
# nnQ-RT-PCR
# Te
# .
# All
# COVID-19
# jb
# ue
# ue
# nnQ-RT-PCR
# eerne
# ce
# u
# ,
# whch
# en
# COVID-19
# jb
# ubrek
# unrelble
# n
# flwe
# .
# Th
# hckng.M
# Hncck
# n
# ’
# ‘
# celebr
# ’
# ,
# he
# ’
# he
# frer
# helh
# ecrer
# wh
# verw
# he
# UK
# hvng
# ne
# f
# he
# hghe
# eh
# ll
# n
# he
# wrl
# fr
# Cv-19
# whl
# brekng
# h
# wn
# lckwn
# rule
# .
# 1/5🚨🚨🚨🚨🚨
# NY
# Se
# Supree
# Cur
# rene
# ll
# fre
# unvccne
# eplee
# ,
# rer
# bckp
# ,
# he
# e
# vle
# rgh
# ,
# ce
# rbrr
# &
# p
# ;
# cprcu
# ,
# ne
# :
# “
# Beng
# vccne
# e
# n
# preven
# n
# nvul
# fr
# cnrcng
# r
# rnng
# Cv-19.
# ...

# %%
str3 = sentence

# %% [markdown]
# # **Sentiment** **Analysis**

# %%
from textblob import TextBlob

# %%
blob1 = TextBlob(str3)
print(blob1.sentiment)
# Out:
# Sentiment(polarity=0.25114927685950417, subjectivity=0.519421487603306)
